# %%
from matplotlib import legend
import matplotlib.pyplot as plt
import pandas as pd

# %%
filename_train = 'e2f_epochs_val_tr/results.csv'
filename_val = 'e2f_epochs_val_tr_x/results.csv'
filename_hold = 'e2f_epochs_hold_tr_x/results.csv'

df_train = pd.read_csv(filename_train)
df_val = pd.read_csv(filename_val)
df_hold = pd.read_csv(filename_hold)
print(df_val.keys())
# Out:
# Index(['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')

# %%
total_train_loss = df_train['train/box_loss'] + df_train['train/cls_loss'] + df_train['train/dfl_loss']
total_val_loss = df_val['val/box_loss'] + df_val['val/cls_loss'] + df_val['val/dfl_loss']
total_hold_loss = df_hold['val/box_loss'] + df_hold['val/cls_loss'] + df_hold['val/dfl_loss']

# %%
plt.plot([2*i for i in range(23)], total_hold_loss, label='hold-out loss')
plt.plot([2*i for i in range(23)], total_val_loss, label='validation loss')
# plt.plot(total_val_loss, label='val loss')
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Total loss')
plt.legend()

# %%
plt.plot(df['train/box_loss'], label='train loss')
plt.plot(df['val/box_loss'], label='val loss')
plt.title('Box loss')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.plot(df['train/box_loss'], label='train loss')
#       2 plt.plot(df['val/box_loss'], label='val loss')
#       3 plt.title('Box loss')
#
# NameError: name 'df' is not defined

# %%
plt.plot(df['train/cls_loss'], label='train loss')
# plt.plot(df['val/cls_loss'], label='val loss')
plt.title('Class loss')
plt.legend()

# %%
plt.plot(df['train/dfl_loss'], label='train loss')
# plt.plot(df['val/dfl_loss'], label='val loss')
plt.title('Dfl loss')
plt.legend()

# %%
plt.plot(df['metrics/mAP50(B)'], label='mAP50')
plt.plot(df['metrics/mAP50-95(B)'], label='mAP50-95')
plt.legend()
plt.title('Metrics mAP')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.plot(df['metrics/mAP50(B)'], label='mAP50')
#       2 plt.plot(df['metrics/mAP50-95(B)'], label='mAP50-95')
#       3 plt.legend()
#
# NameError: name 'df' is not defined

# %%
plt.plot([2*i for i in range(23)], df_val['metrics/precision(B)'], label='Precision validation', c='green', linestyle='dashed')
plt.plot([2*i for i in range(23)], df_val['metrics/recall(B)'], label='Recall validation', c='green')
plt.plot([2*i for i in range(23)], df_hold['metrics/precision(B)'], label='Precision hold-out', c='orange', linestyle='dashed')
plt.plot([2*i for i in range(23)], df_hold['metrics/recall(B)'], label='Recall hold-out', c='orange')
plt.ylabel('Recall and Precision %')
plt.xlabel('Epochs')
# plt.ylim(0,1)
plt.legend()
plt.title('Recall and Precision')
# Out:
# Text(0.5, 1.0, 'Recall and Precision')

# %%
import numpy as np
np.argmax(df['metrics/mAP50(B)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 import numpy as np
# ----> 2 np.argmax(df['metrics/mAP50(B)'])
#
# NameError: name 'df' is not defined

# %%
print((df_val['metrics/recall(B)'][11]))
print(df_hold['metrics/recall(B)'][11])
# Out:
# 0.79851
# 0.7976

# %%
print(df['metrics/precision(B)'][12])
print(df['metrics/precision(B)'][99])
# Out:
# 0.87427
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/virtual_envs/info/lib/python3.10/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 99 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 2
#       1 print(df['metrics/precision(B)'][12])
# ----> 2 print(df['metrics/precision(B)'][99])
#
# File ~/virtual_envs/info/lib/python3.10/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
# ...

# %%
total_train_loss[52-8]
total_val_loss[10]
# Out:
# 200.67309
